# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My Lane --> Structured Content Archetype Clustering

#I chose the Structured Content Archetype Clustering lane because I am interested in discovering patterns in content performance.
#My goal is to group similar content pages based on observable performance metrics and content characteristics to identify different content archetypes.
#These archetypes can help content teams decide whether pages should be protected, refreshed, improved, monitored, merged, or pruned.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## Decision --> Identify different content archetypes based on performance

## Action --> Help content teams to use the clusters in order to decide which content items to protect, refresh, improve, monitor, or prune

## Cost of a wrong recommendation --> Pages may receive the wrong action leading to wasted time 

## The dataset contains many performance signals, making it difficult to identify meaningful patterns using simple rules alone

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

import pandas as pd

df = pd.read_csv(r"C:\Users\PIXEL-PC\Desktop\starter\data\raw\content_refresh_anonymized.csv")

df.head()
df.shape
df.info()
df.describe()

#The starter dataset contains 30,000 content pages and 44 features
# Some features have missing values which will need to be considered during data preparation.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This analysis identifies groups of similar content based on the available data.
# The clusters do not prove why pages perform differently and they should be used to support human decision-making rather than replace it

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
